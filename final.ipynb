# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('dataset/final_project/treino.csv', index_col='id')
test = pd.read_csv('dataset/final_project/teste.csv', index_col='id')

# %% [markdown]
# ## EDA

# %%
train.head()
# Out:
#             col_0      col_1      col_2       col_3       col_4      col_5  \
# id
# 6550   383.962069  31.877400  20.940436  210.180396   67.665680  89.197493
# 66905  419.112165  37.721698  19.783738  276.141957   89.101999  56.345658
# 86340  285.626773  25.531304  15.359399  244.958947   78.950317  86.405010
# 43383  290.917654  38.114595  17.762438  314.317800   98.343497  72.770055
# 10966  410.320248  34.132931  14.044501  272.234285  103.166055  78.884680
#
#            col_6       col_7      col_8     col_9  ...     col_23    col_24  \
# id                                                 ...
# 6550   51.509044   98.440855  26.133755  4.863669  ...  61.830444  8.370885
# 66905  59.991099   99.279104  39.540056  3.975778  ...  93.476850  6.625610
# 86340  50.592107  100.735481  38.039717  5.517197  ...  82.414287  8.161513
# 43383  44.436549  102.890685  35.385339  5.517020  ...  65.195244  8.620515
# 10966  56.229949   66.615012  45.947103  4.474774  ...  55.280394  4.494784
# ...

# %%
test.head()
# Out:
#             col_0      col_1      col_2       col_3      col_4       col_5  \
# id
# 41106  314.340128  15.639150  14.180285  356.118147  88.097735  110.365698
# 51643  289.334313  31.539685  18.677056  250.955371  74.869236  107.926664
# 15356  340.089664  55.175087  17.242063  288.815601  64.493193   72.701397
# 34464  228.341988  43.178079  13.165309  185.239933  87.166077  102.384306
# 92164  307.664328  35.955860  12.615512  255.259554  69.195555   77.420938
#
#            col_6       col_7      col_8     col_9  ...      col_22     col_23  \
# id                                                 ...
# 41106  40.567294  109.347519  45.877448  2.224570  ...  192.869026  63.641602
# 51643  37.478513   97.797010  36.225421  5.482591  ...  141.682762  45.084596
# 15356  29.404480   96.592450  42.024918  8.955035  ...   90.338185  37.516559
# 34464  39.454532   71.344210  38.596012  5.206337  ...  136.025725  86.221804
# ...

# %%
print(len(train))
print(len(test))
# Out:
# 70000
# 30000

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70000 entries, 6550 to 38445
# Data columns (total 33 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col_0   70000 non-null  float64
#  1   col_1   70000 non-null  float64
#  2   col_2   70000 non-null  float64
#  3   col_3   70000 non-null  float64
#  4   col_4   70000 non-null  float64
#  5   col_5   70000 non-null  float64
#  6   col_6   70000 non-null  float64
#  7   col_7   70000 non-null  float64
#  8   col_8   70000 non-null  float64
#  9   col_9   70000 non-null  float64
#  10  col_10  70000 non-null  float64
#  11  col_11  70000 non-null  float64
#  12  col_12  70000 non-null  float64
#  13  col_13  70000 non-null  float64
#  14  col_14  70000 non-null  float64
#  15  col_15  70000 non-null  float64
#  16  col_16  70000 non-null  float64
#  17  col_17  70000 non-null  float64
#  18  col_18  70000 non-null  float64
#  19  col_19  70000 non-null  float64
# ...

# %%
train['col_30'].value_counts()
# Out:
# baixo          28026
# alto           21071
# medio          13953
# irrelevante     6950
# Name: col_30, dtype: int64

# %%
train['target'].value_counts()
# Out:
# 0    32321
# 1     7168
# 2     6572
# 3     5880
# 6     4710
# 4     4685
# 5     4645
# 7     4019
# Name: target, dtype: int64

# %%
train['gender'].value_counts()
# Out:
# male       34439
# female     34213
# unknown     1348
# Name: gender, dtype: int64

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(train.corr())
plt.show()
# Out:
# /var/folders/k0/sr088lv560v19y4dz_tfgq980000gn/T/ipykernel_91734/1041420941.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(train.corr())
